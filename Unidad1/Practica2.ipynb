# %% [markdown]
# <a href="https://colab.research.google.com/github/dani90210/PROBABILIDAD/blob/main/Unidad1/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image](https://github.com/Jose-Gabriel-Rodriguez/Probabilidad/blmain/Cintilla2025.png?raw=true)
#
# #**Probabilidad y estadistica**
#
# ##**Unidad 1**
#
# ###**Practica 2. Máximo, minimo, Rango y dispersión de datos.**
# ### Docente: "Dr. José Gabriel Rodríguez Rivas
# ### Alumno: Daniel Muñoz Valdez

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

fabrica1 = []
for i in range(100):
    numero_aleatorio = round( random.uniform(50, 100), 2 )
    fabrica1.append(numero_aleatorio)
print(fabrica1)

fabrica2 = []
for i in range(100):
    numero_aleatorio2 = round( random.uniform(40, 93), 2 )
    fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [80.84, 66.29, 98.51, 57.97, 77.67, 68.56, 95.35, 63.23, 97.29, 64.39, 65.11, 90.54, 85.9, 90.93, 51.74, 93.04, 52.91, 91.85, 56.45, 75.75, 66.42, 90.92, 59.27, 51.57, 75.67, 85.07, 93.39, 89.63, 79.24, 62.13, 79.41, 60.98, 85.3, 86.51, 88.17, 75.02, 90.31, 96.87, 95.75, 92.66, 81.79, 52.02, 54.88, 94.89, 56.67, 90.74, 50.41, 53.97, 96.51, 56.33, 54.92, 60.02, 76.5, 81.47, 95.65, 59.75, 55.69, 58.78, 64.51, 75.45, 82.12, 64.43, 79.64, 65.14, 73.96, 96.64, 73.9, 89.67, 78.53, 57.81, 93.17, 63.93, 59.99, 59.02, 90.3, 61.46, 60.53, 80.21, 62.53, 57.69, 85.35, 78.97, 56.96, 82.16, 77.75, 65.46, 61.7, 87.1, 65.64, 80.58, 66.48, 63.94, 88.31, 60.67, 60.7, 94.25, 82.93, 89.91, 57.32, 59.42]
# [75.23, 87.77, 86.0, 72.97, 65.49, 82.12, 87.55, 72.52, 57.25, 90.01, 74.96, 41.66, 51.86, 59.17, 80.16, 68.59, 48.21, 91.63, 58.14, 68.93, 44.65, 91.07, 88.45, 64.42, 72.53, 51.52, 40.74, 68.17, 76.33, 56.62, 92.99, 74.6, 92.78, 82.46, 44.47, 81.65, 65.84, 88.17, 88.13, 75.59, 56.67, 71.26, 70.96, 48.82, 46.25, 88.08, 87.76, 53.39, 56.6, 86.58, 51.14, 77.05, 82.6, 53.39, 88.25, 92.59, 92.93, 73.7, 69.29, 66.5, 92.53, 49.7, 66.92, 80.0, 51.08, 64.46, 89.16, 74.52, 78.83, 72.57, 81.76, 83.09, 89.12, 44.37, 73.69, 50.1, 63.35, 44.26, 54.12, 76.66, 54.98, 49.61, 56.42, 78.88, 49.51, 43.83, 64.25, 65.4, 82.75, 44.75, 86.62, 73.58, 44.1, 63.67, 77.35, 71.3, 74.97, 77.94, 47.5, 60.09]

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Estadistica descriptiva de la Fabrica 1 \n",
      "Media =", media1,
      "\n Mediana =", mediana1,
      "\n Moda =", moda1,
      "\n Maximo =", maximo1,
      "\n Minimo =", minimo1,
      "\n Rango =", rango1)
# Out:
# Estadistica descriptiva de la Fabrica 1
#  Media = 74.1583
#  Mediana = 75.56
#  Moda = 80.84
#  Maximo = 98.51
#  Minimo = 50.41
#  Rango = 48.10000000000001

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Estadistica descriptiva de la Fabrica 2 \n", "Media =", media2,
      "\n Mediana =", mediana2,
      "\n Moda =", moda2,
      "\n Maximo =", maximo2,
      "\n Minimo =", minimo2,
      "\n Rango =", rango2)
# Out:
# Estadistica descriptiva de la Fabrica 2
#  Media = 69.23
#  Mediana = 71.91
#  Moda = 53.39
#  Maximo = 92.99
#  Minimo = 40.74
#  Rango = 52.24999999999999

# %%
plt.figure(figsize = (8,6))
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor="black")
plt.axvline(media1, color='b', linestyle= 'dashed', linewidth=2, label=f' Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle= 'dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle= 'dashed', linewidth=2, label=f' Moda={moda1:.2f}')

plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle= 'dashed',
linewidth=2, label=f'Desv. Estándar {desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle= 'dashed',
linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8,6) )
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle= 'dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle= 'dashed', linewidth=2, label=f' Mediana={mediana2: .2f}')
plt.axvline(moda2, color='y', linestyle= 'dashed', linewidth=2, label=f' Moda={moda2:.2f}')

desviacion_estandar_fabrica1 = stdev(fabrica1)
desviacion_estandar_fabrica2 = stdev(fabrica2)

plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar ={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle= 'dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()

print("Desviación estándar de la Fabrica 1:", desviacion_estandar_fabrica1)
print("Desviación estándar de la Fabrica 2:", desviacion_estandar_fabrica2)
# Out:
# Desviación estándar de la Fabrica 1: 14.590623116899222
# Desviación estándar de la Fabrica 2: 15.47498607234895

# %%
import seaborn as sns

# %%
sns.histplot ( x=fabrica1, kde = True, kde_kws = {'bw_adjust':0.5 }, bins=10)
# Out:
# <Axes: ylabel='Count'>
