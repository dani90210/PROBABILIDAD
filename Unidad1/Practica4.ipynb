# %% [markdown]
# <a href="https://colab.research.google.com/github/dani90210/PROBABILIDAD/blob/main/Unidad1/Practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image](https://github.com/lose-Gabriel-Rodriguez/Probabilidad/blob/main/Cintilla2025.png?raw=true)
#
# #**Probabilidad y estadistica**
#
# ## **Unidad 1**
#
# ### **Practica 4. Diagrama de Cajas y Bigotes**
#
# ### Docente: *Dr. José Gabriel Rodriguez Rivas*
#
# ###Alumno: Daniel Muñoz Valdez

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range (100):
 numero_aleatorio = round (random.uniform(50, 100), 2)
 fabrica1.append(numero_aleatorio)
print (fabrica1)
# Out:
# [72.58, 58.81, 93.5, 57.23, 59.34, 90.24, 68.54, 96.84, 96.68, 99.02, 70.83, 59.88, 72.61, 98.44, 90.28, 87.83, 51.02, 55.56, 53.46, 65.43, 85.77, 98.9, 72.74, 89.89, 76.83, 62.51, 83.63, 57.2, 99.76, 77.72, 76.09, 61.09, 69.4, 67.93, 87.7, 59.47, 67.81, 80.33, 68.12, 66.24, 88.13, 74.57, 77.69, 65.28, 99.61, 92.72, 67.44, 64.91, 72.48, 77.62, 65.08, 58.26, 64.94, 57.43, 84.85, 90.44, 68.72, 58.34, 87.38, 70.42, 77.16, 50.62, 70.15, 83.11, 85.37, 59.9, 58.07, 92.19, 50.92, 80.03, 75.99, 50.91, 91.49, 99.36, 88.69, 59.18, 90.3, 98.78, 80.56, 68.29, 73.27, 87.33, 86.62, 59.56, 56.41, 89.49, 59.86, 66.81, 67.23, 74.25, 97.82, 77.9, 90.82, 53.88, 58.21, 95.76, 66.73, 63.76, 73.41, 92.05]

# %%
fabrica2 = []
for i in range (100):
 numero_aleatorio = round (random.uniform(40, 90), 2)
 fabrica2.append(numero_aleatorio)
print (fabrica2)
# Out:
# [70.61, 42.28, 46.36, 50.47, 51.96, 84.9, 77.22, 79.07, 88.5, 64.25, 80.76, 73.43, 58.84, 88.42, 79.72, 80.83, 78.72, 85.83, 89.25, 66.44, 48.21, 85.74, 50.37, 73.42, 48.65, 54.86, 71.27, 65.5, 81.97, 68.18, 64.06, 47.0, 55.94, 45.81, 81.56, 50.0, 64.44, 85.57, 64.5, 58.53, 66.29, 55.04, 67.57, 58.71, 76.49, 71.47, 48.87, 81.4, 76.91, 87.15, 80.88, 40.77, 87.51, 40.37, 66.74, 44.14, 77.63, 74.27, 45.56, 66.85, 67.67, 51.28, 69.37, 89.67, 83.58, 55.16, 71.95, 58.19, 70.79, 58.08, 89.6, 75.45, 78.83, 78.86, 81.82, 48.26, 64.34, 57.52, 41.04, 66.1, 67.67, 75.97, 89.35, 78.58, 85.63, 66.01, 58.76, 54.19, 79.63, 73.36, 70.88, 49.02, 59.83, 84.37, 71.64, 81.75, 43.57, 43.52, 47.62, 87.12]

# %%
plt.boxplot(fabrica1)
plt.ylabel ('produccion en mts')
plt.title ('produccion de la fabrica1')
plt.show()

# %%
plt.boxplot(fabrica2)
plt.ylabel ('produccion en mts')
plt.title ('produccion de la fabrica2')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots (nrows =1 , ncols = 2, figsize=(9,4))
bplot1 = ax1.boxplot (fabrica1,
                      vert=True,
                      patch_artist = True)
ax1.set_title ('Produccion fabrica1')
bplot2 = ax2.boxplot (fabrica2,
                      vert = True,
                      patch_artist=True)
ax2.set_title('Produccion Fabrica 2')
plt.show()

# %%
fabrica1.append (150)
print (fabrica1)
# Out:
# [72.58, 58.81, 93.5, 57.23, 59.34, 90.24, 68.54, 96.84, 96.68, 99.02, 70.83, 59.88, 72.61, 98.44, 90.28, 87.83, 51.02, 55.56, 53.46, 65.43, 85.77, 98.9, 72.74, 89.89, 76.83, 62.51, 83.63, 57.2, 99.76, 77.72, 76.09, 61.09, 69.4, 67.93, 87.7, 59.47, 67.81, 80.33, 68.12, 66.24, 88.13, 74.57, 77.69, 65.28, 99.61, 92.72, 67.44, 64.91, 72.48, 77.62, 65.08, 58.26, 64.94, 57.43, 84.85, 90.44, 68.72, 58.34, 87.38, 70.42, 77.16, 50.62, 70.15, 83.11, 85.37, 59.9, 58.07, 92.19, 50.92, 80.03, 75.99, 50.91, 91.49, 99.36, 88.69, 59.18, 90.3, 98.78, 80.56, 68.29, 73.27, 87.33, 86.62, 59.56, 56.41, 89.49, 59.86, 66.81, 67.23, 74.25, 97.82, 77.9, 90.82, 53.88, 58.21, 95.76, 66.73, 63.76, 73.41, 92.05, 150]

# %%
fig, (ax1, ax2) = plt.subplots (nrows =1 , ncols = 2, figsize=(9,4))
bplot1 = ax1.boxplot (fabrica1,
                      vert=True,
                      patch_artist = True)
ax1.set_title ('Produccion fabrica1')
bplot2 = ax2.boxplot (fabrica2,
                      vert = True,
                      patch_artist=True)
ax2.set_title('Produccion Fabrica 2')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots (nrows =1 , ncols = 2, figsize=(9,4))
bplot1 = ax1.boxplot (fabrica1,
                      vert=True,
                      patch_artist = True)
ax1.set_title ('Produccion fabrica1')
ax1.set_ylim (0, 160)

bplot2 = ax2.boxplot (fabrica2,
                      vert = True,
                      patch_artist=True)
ax2.set_title('Produccion Fabrica 1')
ax2.set_ylim (0, 100)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots (nrows =1 , ncols = 2, figsize=(9,4))
bplot1 = ax1.boxplot (fabrica1,
                      vert=True,
                      patch_artist = True)
ax1.set_title ('Produccion fabrica1')
ax1.set_ylim (0, 160)

bplot2 = ax2.boxplot (fabrica2,
                      vert = True,
                      patch_artist=True)
ax2.set_title('Produccion Fabrica 2')
ax2.set_ylim (0, 100)
plt.show()
