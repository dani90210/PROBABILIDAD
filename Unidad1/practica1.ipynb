# %% [markdown]
# <a href="https://colab.research.google.com/github/dani90210/PROBABILIDAD/blob/main/Unidad1/practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probabilidad y estadistica**
# ##Grupo 2-Y
# ##Unidad1
# Decente: Jose Gabriel Rodriguez Rivas
#
# Alumno: Daniel Muñoz Valdez
#
# **Practica1: Medidas de Tendencia Central e Histogramas**

# %%
import statistics as stats

grupoa = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print(grupoa)

# Promedio con sum()
promedio = sum(grupoa) / len(grupoa)
print("Promedio con sum:", promedio)

# Promedio con statistics.mean()
promedio2 = stats.mean(grupoa)
print("Promedio con mean:", promedio2)

# Mediana
mediana = stats.median(grupoa)
print("Mediana:", mediana)

# Multimoda
moda2 = stats.multimode(grupoa)
print("Moda(s):", moda2)

# Lista de tiempos
tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.5, 20, 15.10, 17.20]
print(tiempos100mts)

# Promedio
print("El tiempo promedio de los corredores:", stats.mean(tiempos100mts))

# Mediana
mediana = stats.median(tiempos100mts)
print("La mediana de los tiempos de los corredores es:", mediana)

# Moda
moda = stats.mode(tiempos100mts)
print("La moda de los tiempos es:", moda)

# Multimodas
multimodas = stats.multimode(tiempos100mts)
print("Las modas de los tiempos son:", multimodas)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# Promedio con sum: 75.33333333333333
# Promedio con mean: 75.33333333333333
# Mediana: 76.5
# Moda(s): [70, 100]
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.5, 20, 15.1, 17.2]
# El tiempo promedio de los corredores: 17.291999999999998
# La mediana de los tiempos de los corredores es: 17.2
# La moda de los tiempos es: 15.1
# Las modas de los tiempos son: [15.1, 17.2]

# %%
import random

# %%
from statistics import*

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(0,100),2)
  fabrica1.append(numero_aleatorio)
  print(fabrica1)
# Out:
# [16.18]
# [16.18, 93.86]
# [16.18, 93.86, 73.09]
# [16.18, 93.86, 73.09, 41.99]
# [16.18, 93.86, 73.09, 41.99, 61.67]
# [16.18, 93.86, 73.09, 41.99, 61.67, 41.46]
# [16.18, 93.86, 73.09, 41.99, 61.67, 41.46, 74.9]
# [16.18, 93.86, 73.09, 41.99, 61.67, 41.46, 74.9, 36.15]
# [16.18, 93.86, 73.09, 41.99, 61.67, 41.46, 74.9, 36.15, 33.6]
# [16.18, 93.86, 73.09, 41.99, 61.67, 41.46, 74.9, 36.15, 33.6, 79.24]
# [16.18, 93.86, 73.09, 41.99, 61.67, 41.46, 74.9, 36.15, 33.6, 79.24, 27.02]
# [16.18, 93.86, 73.09, 41.99, 61.67, 41.46, 74.9, 36.15, 33.6, 79.24, 27.02, 71.42]
# [16.18, 93.86, 73.09, 41.99, 61.67, 41.46, 74.9, 36.15, 33.6, 79.24, 27.02, 71.42, 60.96]
# [16.18, 93.86, 73.09, 41.99, 61.67, 41.46, 74.9, 36.15, 33.6, 79.24, 27.02, 71.42, 60.96, 94.88]
# [16.18, 93.86, 73.09, 41.99, 61.67, 41.46, 74.9, 36.15, 33.6, 79.24, 27.02, 71.42, 60.96, 94.88, 27.31]
# [16.18, 93.86, 73.09, 41.99, 61.67, 41.46, 74.9, 36.15, 33.6, 79.24, 27.02, 71.42, 60.96, 94.88, 27.31, 73.91]
# ...

# %%
fabrica2= []
for i in range(100):
  numero_aleatorio = round(random.uniform(40,93),2)
  fabrica2.append(numero_aleatorio)
  print(fabrica2)
# Out:
# [48.16]
# [48.16, 82.11]
# [48.16, 82.11, 49.29]
# [48.16, 82.11, 49.29, 51.86]
# [48.16, 82.11, 49.29, 51.86, 71.88]
# [48.16, 82.11, 49.29, 51.86, 71.88, 91.74]
# [48.16, 82.11, 49.29, 51.86, 71.88, 91.74, 85.65]
# [48.16, 82.11, 49.29, 51.86, 71.88, 91.74, 85.65, 57.89]
# [48.16, 82.11, 49.29, 51.86, 71.88, 91.74, 85.65, 57.89, 60.85]
# [48.16, 82.11, 49.29, 51.86, 71.88, 91.74, 85.65, 57.89, 60.85, 48.37]
# [48.16, 82.11, 49.29, 51.86, 71.88, 91.74, 85.65, 57.89, 60.85, 48.37, 52.62]
# [48.16, 82.11, 49.29, 51.86, 71.88, 91.74, 85.65, 57.89, 60.85, 48.37, 52.62, 80.71]
# [48.16, 82.11, 49.29, 51.86, 71.88, 91.74, 85.65, 57.89, 60.85, 48.37, 52.62, 80.71, 91.37]
# [48.16, 82.11, 49.29, 51.86, 71.88, 91.74, 85.65, 57.89, 60.85, 48.37, 52.62, 80.71, 91.37, 70.03]
# [48.16, 82.11, 49.29, 51.86, 71.88, 91.74, 85.65, 57.89, 60.85, 48.37, 52.62, 80.71, 91.37, 70.03, 47.83]
# [48.16, 82.11, 49.29, 51.86, 71.88, 91.74, 85.65, 57.89, 60.85, 48.37, 52.62, 80.71, 91.37, 70.03, 47.83, 53.37]
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("producciond de la fabrica1")
# Out:
# Text(0.5, 1.0, 'producciond de la fabrica1')

# %%
plt.hist(fabrica2)
plt.title("producción diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'producción diaria de la fabrica 2')

# %%
media1 = mean (fabrica1)
mediana1 = median (fabrica1)
moda1 = mode (fabrica1)

print ("valores de la fabrica1")
print ("la media es =", media1)
print ("la mediana es =", mediana1)
print ("la moda es=", moda1)
# Out:
# valores de la fabrica1
# la media es = 54.0154
# la mediana es = 56.815
# la moda es= 16.18

# %%
media2 = mean (fabrica2)
mediana2 = median (fabrica2)
moda2 = mode (fabrica2)

print("valores de la fabrica2")
print ("la media es =", media2)
print ("la mediana es =", mediana2)
print("la moda es=", moda2)
# Out:
# valores de la fabrica2
# la media es = 67.7547
# la mediana es = 68.765
# la moda es= 70.09

# %%
fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize=(10, 5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
plt.hist (fabrica1, bins=10, alpha=0.2, color='b',  edgecolor = "black")
plt.axvline (media1, color = 'b', linestyle ='dashed', linewidth = 2, label = "Media1")
plt.axvline (mediana1, color = 'g', linestyle ='dashed', linewidth = 2, label = "Mediana1")
plt.axvline (moda1, color = 'r', linestyle ='dashed', linewidth = 2, label = "Moda1")
plt.xlabel ('Valor')
plt.ylabel ('Frecuencia')
plt.title ("Produccion diaria de la fabrica1")
plt.legend()
plt.show()

# %%
plt.hist (fabrica2, bins=10, alpha=0.2, color='b',  edgecolor = "black")
plt.axvline (media2, color = 'b', linestyle ='dashed', linewidth = 2, label = "Media2")
plt.axvline (mediana2, color = 'g', linestyle ='dashed', linewidth = 2, label = "Mediana2")
plt.axvline (moda2, color = 'r', linestyle ='dashed', linewidth = 2, label = "Moda2")
plt.xlabel ('Valor')
plt.ylabel ('Frecuencia')
plt.title ("Produccion diaria de la fabrica2")
plt.legend()
plt.show()
